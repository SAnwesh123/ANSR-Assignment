# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('mobile_events_2020.csv',sep = ';')

# %%
df.head(10)
# Out:
#                            anonymous_id business_zoned context_app_version  \
# 0  9DDC5BCD-0477-4E83-A32A-51013DA0A4E7        Hamburg              3.1.13
# 1  5592E78E-CE87-4258-B8D7-DD834A687A1E        Hamburg              3.1.13
# 2  5592E78E-CE87-4258-B8D7-DD834A687A1E        Hamburg              3.1.13
# 3  5592E78E-CE87-4258-B8D7-DD834A687A1E        Hamburg              3.1.13
# 4  5592E78E-CE87-4258-B8D7-DD834A687A1E        Hamburg              3.1.13
# 5  5592E78E-CE87-4258-B8D7-DD834A687A1E        Hamburg              3.1.13
# 6  9DDC5BCD-0477-4E83-A32A-51013DA0A4E7        Hamburg              3.1.13
# 7  9DDC5BCD-0477-4E83-A32A-51013DA0A4E7        Hamburg              3.1.13
# 8  9DDC5BCD-0477-4E83-A32A-51013DA0A4E7        Hamburg              3.1.13
# 9  9DDC5BCD-0477-4E83-A32A-51013DA0A4E7        Hamburg              3.1.13
#
#                       context_device_id context_os_name  \
# 0  7A718FF6-584F-40E2-939D-224231295B1E             iOS
# ...

# %%
df.tail(10)
# Out:
#                                 anonymous_id business_zoned  \
# 102412  06722623-7FBB-4368-90A5-9770433A41EB        Hamburg
# 102413  7C6780F1-B0F4-4525-B008-09591C5DD214        Hamburg
# 102414  7C6780F1-B0F4-4525-B008-09591C5DD214        Hamburg
# 102415  7C6780F1-B0F4-4525-B008-09591C5DD214        Hamburg
# 102416  7C6780F1-B0F4-4525-B008-09591C5DD214        Hamburg
# 102417  7C6780F1-B0F4-4525-B008-09591C5DD214        Hamburg
# 102418  E1F50677-B43A-47DE-88A9-BD5A552B7D9E        Hamburg
# 102419  3569EA33-48C7-4E02-8B22-9E613C40481C        Hamburg
# 102420  46f981e2-d66d-43da-922d-38f4c14d02dd        Hamburg
# 102421  7e842b89-f8e9-492d-978d-8dda318eca15        Hamburg
#
#        context_app_version                     context_device_id  \
# 102412              3.1.13  FAE8C3BE-C655-4AB9-AB3F-D80380D8D6FE
# 102413              3.1.13  0B5D7461-69F7-436A-8960-B806EEDCA5B4
# 102414              3.1.13  0B5D7461-69F7-436A-8960-B806EEDCA5B4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102422 entries, 0 to 102421
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   anonymous_id         102422 non-null  object
#  1   business_zoned       102422 non-null  object
#  2   context_app_version  102422 non-null  object
#  3   context_device_id    102422 non-null  object
#  4   context_os_name      102422 non-null  object
#  5   event_name           102422 non-null  object
#  6   received_at          102422 non-null  object
#  7   created_at           102422 non-null  object
# dtypes: object(8)
# memory usage: 6.3+ MB

# %%
string_search = 'Scooter Selected - Auto'

percentage_with_intention = (df['event_name'].isin([string_search]).sum() / df.shape[0]) * 100

# %%
percentage_with_intention
# Out:
# 8.528441155220557

# %% [markdown]
# 8.53% of sessions with an intention to book a scooter

# %% [markdown]
# 2. What is the % of sessions with a successful booking? 3. What determines, according to you, an intention to book?
# 4. What are factors, according to you, determining a successful booking?
# 5. Do you have any hypotheses after exploring this data? If yes, please add them.

# %% [markdown]
# # Question #2

# %%
string_search = 'Qr Scanner - Scanned Succeeded'

percentage_with_intention = (df['event_name'].isin([string_search]).sum() / df.shape[0]) * 100

# %%
percentage_with_intention
# Out:
# 4.810489933803284

# %% [markdown]
# # Question #3

# %% [raw]
# When A user scanned a code its successful then its called a succesful booking.

# %% [markdown]
# # Question #4

# %%
Yes, Hypothsis testing can be done, We can use 

1.Hypothesis: Can we predict the "event_name" based on other variables like "business_zoned" or "context_app_version"?
    Test: Logistic regression for categorical outcomes or linear regression for continuous outcomes.
        
2. Proportion Test:

Hypothesis: Is there a significant difference in the proportion of "Scooter Selected - Auto" events between iOS and Android users?
Test: Chi-squared test for proportions.
    
3.Mean Test:

Hypothesis: Is there a significant difference in the mean "received_at" time between "Application Opened" events and "Qr Scanner Tapped" events?
Test: Two-sample t-test or ANOVA (Analysis of Variance) if comparing multiple event types.
